# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
qb_df = pd.read_csv("2010_QB_stats.csv")

# %%
qb_df.head()
# Out:
#                         qb  att  cmp  yds  ypa  td  int   lg  sack  loss  \
# 0      Brett FavreB. Favre   27   15  171  6.3   1    1   33     1     9
# 1       Drew BreesD. Brees   36   27  237  6.6   1    0  29t     1     8
# 2       Chad HenneC. Henne   34   21  182  5.4   0    0   21     3    18
# 3  Trent EdwardsT. Edwards   34   18  139  4.1   1    0  31t     3    23
# 4         Matt RyanM. Ryan   44   27  252  5.7   0    1   23     2    15
#
#     rate  game_points home_away  year
# 0   71.7            9      away  2010
# 1  101.3           14      home  2010
# 2   75.9           15      away  2010
# 3   73.0           10      home  2010
# 4   67.6            9      away  2010

# %%
qb_col = qb_df["qb"].tolist()

# %%
qb_col
# Out:
# ['Brett FavreB.\xa0Favre',
#  'Drew BreesD.\xa0Brees',
#  'Chad HenneC.\xa0Henne',
#  'Trent EdwardsT.\xa0Edwards',
#  'Matt RyanM.\xa0Ryan',
#  'Dennis DixonD.\xa0Dixon',
#  'Kyle OrtonK.\xa0Orton',
#  'David GarrardD.\xa0Garrard',
#  'Peyton ManningP.\xa0Manning',
#  'Matt SchaubM.\xa0Schaub',
#  'Jake DelhommeJ.\xa0Delhomme',
#  'Joshua CribbsJ.\xa0Cribbs',
#  'Josh FreemanJ.\xa0Freeman',
#  'Matt MooreM.\xa0Moore',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Eli ManningE.\xa0Manning',
#  'Carson PalmerC.\xa0Palmer',
#  'Tom BradyT.\xa0Brady',
#  'Jason CampbellJ.\xa0Campbell',
#  'Vince YoungV.\xa0Young',
#  'Shaun HillS.\xa0Hill',
#  'Matthew StaffordM.\xa0Stafford',
#  'Jay CutlerJ.\xa0Cutler',
#  'Derek AndersonD.\xa0Anderson',
#  'Sam BradfordS.\xa0Bradford',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Michael VickM.\xa0Vick',
#  'Kevin KolbK.\xa0Kolb',
#  'Alex SmithA.\xa0Smith',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Tony RomoT.\xa0Romo',
#  'Marion BarberM.\xa0Barber',
#  'Donovan McNabbD.\xa0McNabb',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Mark SanchezM.\xa0Sanchez',
#  'Philip RiversP.\xa0Rivers',
#  'Matt CasselM.\xa0Cassel',
#  'Charlie BatchC.\xa0Batch',
#  'Dennis DixonD.\xa0Dixon',
#  'Kerry CollinsK.\xa0Collins',
#  'Vince YoungV.\xa0Young',
#  'Josh FreemanJ.\xa0Freeman',
#  'Micheal SpurlockM.\xa0Spurlock',
#  'Matt MooreM.\xa0Moore',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Matt CasselM.\xa0Cassel',
#  'Seneca WallaceS.\xa0Wallace',
#  'Chad HenneC.\xa0Henne',
#  'Brett FavreB.\xa0Favre',
#  'Derek AndersonD.\xa0Anderson',
#  'Max HallM.\xa0Hall',
#  'Matt RyanM.\xa0Ryan',
#  'Michael VickM.\xa0Vick',
#  'Shaun HillS.\xa0Hill',
#  'Jay CutlerJ.\xa0Cutler',
#  'Tony RomoT.\xa0Romo',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Carson PalmerC.\xa0Palmer',
#  'Trent EdwardsT.\xa0Edwards',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Sam BradfordS.\xa0Bradford',
#  'Bruce GradkowskiB.\xa0Gradkowski',
#  'Jason CampbellJ.\xa0Campbell',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Kyle OrtonK.\xa0Orton',
#  'Matt SchaubM.\xa0Schaub',
#  'Donovan McNabbD.\xa0McNabb',
#  'Tom BradyT.\xa0Brady',
#  'Mark SanchezM.\xa0Sanchez',
#  'David GarrardD.\xa0Garrard',
#  'Luke McCownL.\xa0McCown',
#  'Philip RiversP.\xa0Rivers',
#  'Eli ManningE.\xa0Manning',
#  'Peyton ManningP.\xa0Manning',
#  'Drew BreesD.\xa0Brees',
#  'Alex SmithA.\xa0Smith',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'Tom BradyT.\xa0Brady',
#  'Shaun HillS.\xa0Hill',
#  'Brett FavreB.\xa0Favre',
#  'Carson PalmerC.\xa0Palmer',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Matt RyanM.\xa0Ryan',
#  'Drew BreesD.\xa0Brees',
#  'Charlie BatchC.\xa0Batch',
#  'Josh FreemanJ.\xa0Freeman',
#  'Josh JohnsonJ.\xa0Johnson',
#  'Seneca WallaceS.\xa0Wallace',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Anquan BoldinA.\xa0Boldin',
#  'Vince YoungV.\xa0Young',
#  'Eli ManningE.\xa0Manning',
#  'Alex SmithA.\xa0Smith',
#  'Matt CasselM.\xa0Cassel',
#  'Tony RomoT.\xa0Romo',
#  'Matt SchaubM.\xa0Schaub',
#  'Donovan McNabbD.\xa0McNabb',
#  'Sam BradfordS.\xa0Bradford',
#  'Michael VickM.\xa0Vick',
#  'David GarrardD.\xa0Garrard',
#  'Philip RiversP.\xa0Rivers',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Bruce GradkowskiB.\xa0Gradkowski',
#  'Derek AndersonD.\xa0Anderson',
#  'Peyton ManningP.\xa0Manning',
#  'Kyle OrtonK.\xa0Orton',
#  'Mark SanchezM.\xa0Sanchez',
#  'Chad HenneC.\xa0Henne',
#  'Ronnie BrownR.\xa0Brown',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Jay CutlerJ.\xa0Cutler',
#  'Mark SanchezM.\xa0Sanchez',
#  'Mark BrunellM.\xa0Brunell',
#  'Brad SmithB.\xa0Smith',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Michael RobinsonM.\xa0Robinson',
#  'Sam BradfordS.\xa0Bradford',
#  'Alex SmithA.\xa0Smith',
#  'Matt RyanM.\xa0Ryan',
#  'Shaun HillS.\xa0Hill',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Carson PalmerC.\xa0Palmer',
#  'Seneca WallaceS.\xa0Wallace',
#  'Kyle OrtonK.\xa0Orton',
#  'Vince YoungV.\xa0Young',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Drew BreesD.\xa0Brees',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Charlie BatchC.\xa0Batch',
#  'Peyton ManningP.\xa0Manning',
#  'David GarrardD.\xa0Garrard',
#  'Matt SchaubM.\xa0Schaub',
#  'Bruce GradkowskiB.\xa0Gradkowski',
#  'Donovan McNabbD.\xa0McNabb',
#  'Kevin KolbK.\xa0Kolb',
#  'Michael VickM.\xa0Vick',
#  'Derek AndersonD.\xa0Anderson',
#  'Max HallM.\xa0Hall',
#  'Philip RiversP.\xa0Rivers',
#  'Billy VolekB.\xa0Volek',
#  'Todd CollinsT.\xa0Collins',
#  'Jay CutlerJ.\xa0Cutler',
#  'Caleb HanieC.\xa0Hanie',
#  'Eli ManningE.\xa0Manning',
#  'Tom BradyT.\xa0Brady',
#  'Chad HenneC.\xa0Henne',
#  'Tyler ThigpenT.\xa0Thigpen',
#  'Todd CollinsT.\xa0Collins',
#  'Caleb HanieC.\xa0Hanie',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Matt MooreM.\xa0Moore',
#  'Matt CasselM.\xa0Cassel',
#  'Peyton ManningP.\xa0Manning',
#  'Matt RyanM.\xa0Ryan',
#  'Jake DelhommeJ.\xa0Delhomme',
#  'Seneca WallaceS.\xa0Wallace',
#  'Joshua CribbsJ.\xa0Cribbs',
#  'Kyle OrtonK.\xa0Orton',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Eli ManningE.\xa0Manning',
#  'Matt SchaubM.\xa0Schaub',
#  'Sam BradfordS.\xa0Bradford',
#  'Shaun HillS.\xa0Hill',
#  'Jahvid BestJ.\xa0Best',
#  'Drew StantonD.\xa0Stanton',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Donovan McNabbD.\xa0McNabb',
#  'Josh FreemanJ.\xa0Freeman',
#  'Josh JohnsonJ.\xa0Johnson',
#  'Carson PalmerC.\xa0Palmer',
#  'David GarrardD.\xa0Garrard',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'Drew BreesD.\xa0Brees',
#  'Max HallM.\xa0Hall',
#  'Derek AndersonD.\xa0Anderson',
#  'Philip RiversP.\xa0Rivers',
#  'Jason CampbellJ.\xa0Campbell',
#  'Bruce GradkowskiB.\xa0Gradkowski',
#  'Vince YoungV.\xa0Young',
#  'Tony RomoT.\xa0Romo',
#  'Kevin KolbK.\xa0Kolb',
#  'Alex SmithA.\xa0Smith',
#  'Brett FavreB.\xa0Favre',
#  'Mark SanchezM.\xa0Sanchez',
#  'Matt RyanM.\xa0Ryan',
#  'Kevin KolbK.\xa0Kolb',
#  'Philip RiversP.\xa0Rivers',
#  'Sam BradfordS.\xa0Bradford',
#  'Drew BreesD.\xa0Brees',
#  'Josh FreemanJ.\xa0Freeman',
#  'Josh JohnsonJ.\xa0Johnson',
#  'Drew StantonD.\xa0Stanton',
#  'Shaun HillS.\xa0Hill',
#  'Eli ManningE.\xa0Manning',
#  'Chad HenneC.\xa0Henne',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Jay CutlerJ.\xa0Cutler',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Tom BradyT.\xa0Brady',
#  'Colt McCoyC.\xa0McCoy',
#  'Joshua CribbsJ.\xa0Cribbs',
#  'Ben RoethlisbergerB.\xa0Roethlisberger',
#  'Matt CasselM.\xa0Cassel',
#  'Matt SchaubM.\xa0Schaub',
#  'Mark SanchezM.\xa0Sanchez',
#  'Kyle OrtonK.\xa0Orton',
#  'Jason CampbellJ.\xa0Campbell',
#  'Alex SmithA.\xa0Smith',
#  'Tony RomoT.\xa0Romo',
#  'Brett FavreB.\xa0Favre',
#  'Peyton ManningP.\xa0Manning',
#  'Donovan McNabbD.\xa0McNabb',
#  'Kerry CollinsK.\xa0Collins',
#  'Vince YoungV.\xa0Young',
#  'Trent EdwardsT.\xa0Edwards',
#  'David GarrardD.\xa0Garrard',
#  'Kevin KolbK.\xa0Kolb',
#  'Kerry CollinsK.\xa0Collins',
#  'Alex SmithA.\xa0Smith',
#  'David CarrD.\xa0Carr',
#  'Matt MooreM.\xa0Moore',
#  'Todd BoumanT.\xa0Bouman',
#  'Matt CasselM.\xa0Cassel',
#  'Ben RoethlisbergerB.\xa0Roethlisberger',
#  'Chad HenneC.\xa0Henne',
#  'Carson PalmerC.\xa0Palmer',
#  'Matt RyanM.\xa0Ryan',
#  'Donovan McNabbD.\xa0McNabb',
#  'Jay CutlerJ.\xa0Cutler',
#  'Colt McCoyC.\xa0McCoy',
#  'Peyton HillisP.\xa0Hillis',
#  'Drew BreesD.\xa0Brees',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Sam BradfordS.\xa0Bradford',
#  'Josh FreemanJ.\xa0Freeman',
#  'Derek AndersonD.\xa0Anderson',
#  'Max HallM.\xa0Hall',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Jason CampbellJ.\xa0Campbell',
#  'Kyle OrtonK.\xa0Orton',
#  'Tom BradyT.\xa0Brady',
#  'Philip RiversP.\xa0Rivers',
#  'Brett FavreB.\xa0Favre',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Matt FlynnM.\xa0Flynn',
#  'Eli ManningE.\xa0Manning',
#  'Jon KitnaJ.\xa0Kitna',
#  'Tony RomoT.\xa0Romo',
#  'Matt MooreM.\xa0Moore',
#  'Sam BradfordS.\xa0Bradford',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'Matt CasselM.\xa0Cassel',
#  'David GarrardD.\xa0Garrard',
#  'Jon KitnaJ.\xa0Kitna',
#  'Chad HenneC.\xa0Henne',
#  'Carson PalmerC.\xa0Palmer',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Mark SanchezM.\xa0Sanchez',
#  'Donovan McNabbD.\xa0McNabb',
#  'Rex GrossmanR.\xa0Grossman',
#  'Matthew StaffordM.\xa0Stafford',
#  'Kyle OrtonK.\xa0Orton',
#  'Troy SmithT.\xa0Smith',
#  'Vince YoungV.\xa0Young',
#  'Kerry CollinsK.\xa0Collins',
#  'Philip RiversP.\xa0Rivers',
#  'Josh FreemanJ.\xa0Freeman',
#  'Derek AndersonD.\xa0Anderson',
#  'Max HallM.\xa0Hall',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Jason CampbellJ.\xa0Campbell',
#  'Brett FavreB.\xa0Favre',
#  'Tarvaris JacksonT.\xa0Jackson',
#  'Tom BradyT.\xa0Brady',
#  'Ben RoethlisbergerB.\xa0Roethlisberger',
#  'Drew BreesD.\xa0Brees',
#  'Matt SchaubM.\xa0Schaub',
#  'Peyton ManningP.\xa0Manning',
#  'Philip RiversP.\xa0Rivers',
#  'Matt SchaubM.\xa0Schaub',
#  'Chad HenneC.\xa0Henne',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Sam KochS.\xa0Koch',
#  'Jay CutlerJ.\xa0Cutler',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'Josh FreemanJ.\xa0Freeman',
#  'Matt RyanM.\xa0Ryan',
#  'Tom BradyT.\xa0Brady',
#  'Brian HoyerB.\xa0Hoyer',
#  'Colt McCoyC.\xa0McCoy',
#  'Drew BreesD.\xa0Brees',
#  'Chase DanielC.\xa0Daniel',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Tony PikeT.\xa0Pike',
#  'Matt MooreM.\xa0Moore',
#  'Derek AndersonD.\xa0Anderson',
#  'Steve BreastonS.\xa0Breaston',
#  'Brett FavreB.\xa0Favre',
#  'Mark SanchezM.\xa0Sanchez',
#  'Matthew StaffordM.\xa0Stafford',
#  'Drew StantonD.\xa0Stanton',
#  'Eli ManningE.\xa0Manning',
#  'Charlie WhitehurstC.\xa0Whitehurst',
#  'Matt CasselM.\xa0Cassel',
#  'Jason CampbellJ.\xa0Campbell',
#  'Darren McFaddenD.\xa0McFadden',
#  'Peyton ManningP.\xa0Manning',
#  'Michael VickM.\xa0Vick',
#  'Jon KitnaJ.\xa0Kitna',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Matt FlynnM.\xa0Flynn',
#  'Ben RoethlisbergerB.\xa0Roethlisberger',
#  'Antwaan Randle ElA.\xa0Randle El',
#  'Carson PalmerC.\xa0Palmer',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Matt RyanM.\xa0Ryan',
#  'Shaun HillS.\xa0Hill',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'Matt SchaubM.\xa0Schaub',
#  'David GarrardD.\xa0Garrard',
#  'Kerry CollinsK.\xa0Collins',
#  'Vince YoungV.\xa0Young',
#  'Chad HenneC.\xa0Henne',
#  'Tyler ThigpenT.\xa0Thigpen',
#  'Chad PenningtonC.\xa0Pennington',
#  'Brandon MarshallB.\xa0Marshall',
#  'Brett FavreB.\xa0Favre',
#  'Jay CutlerJ.\xa0Cutler',
#  'Mark SanchezM.\xa0Sanchez',
#  'Colt McCoyC.\xa0McCoy',
#  'Carson PalmerC.\xa0Palmer',
#  'Peyton ManningP.\xa0Manning',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Josh FreemanJ.\xa0Freeman',
#  'Matt CasselM.\xa0Cassel',
#  'Kyle OrtonK.\xa0Orton',
#  'Tim TebowT.\xa0Tebow',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Charlie WhitehurstC.\xa0Whitehurst',
#  'Derek AndersonD.\xa0Anderson',
#  'Jon KitnaJ.\xa0Kitna',
#  'Eli ManningE.\xa0Manning',
#  'Sam BradfordS.\xa0Bradford',
#  'Troy SmithT.\xa0Smith',
#  'Tom BradyT.\xa0Brady',
#  'Ben RoethlisbergerB.\xa0Roethlisberger',
#  'Michael VickM.\xa0Vick',
#  'Donovan McNabbD.\xa0McNabb',
#  'Jay CutlerJ.\xa0Cutler',
#  'Tyler ThigpenT.\xa0Thigpen',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Matt FlynnM.\xa0Flynn',
#  'Brett FavreB.\xa0Favre',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Brian St. PierreB.\xa0St. Pierre',
#  'Matt SchaubM.\xa0Schaub',
#  'Mark SanchezM.\xa0Sanchez',
#  'Donovan McNabbD.\xa0McNabb',
#  'Vince YoungV.\xa0Young',
#  'Rusty SmithR.\xa0Smith',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'Carson PalmerC.\xa0Palmer',
#  'Jordan PalmerJ.\xa0Palmer',
#  'Colt McCoyC.\xa0McCoy',
#  'David GarrardD.\xa0Garrard',
#  'Maurice Jones-DrewM.\xa0Jones-Drew',
#  'Shaun HillS.\xa0Hill',
#  'Jon KitnaJ.\xa0Kitna',
#  'Bruce GradkowskiB.\xa0Gradkowski',
#  'Jason CampbellJ.\xa0Campbell',
#  'Ben RoethlisbergerB.\xa0Roethlisberger',
#  'Derek AndersonD.\xa0Anderson',
#  'Matt CasselM.\xa0Cassel',
#  'Matt RyanM.\xa0Ryan',
#  'Sam BradfordS.\xa0Bradford',
#  'Josh FreemanJ.\xa0Freeman',
#  'Josh JohnsonJ.\xa0Johnson',
#  'Micheal SpurlockM.\xa0Spurlock',
#  'Troy SmithT.\xa0Smith',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Drew BreesD.\xa0Brees',
#  'Peyton ManningP.\xa0Manning',
#  'Tom BradyT.\xa0Brady',
#  'Eli ManningE.\xa0Manning',
#  'Michael VickM.\xa0Vick',
#  'Kyle OrtonK.\xa0Orton',
#  'Philip RiversP.\xa0Rivers',
#  'Patrick CraytonP.\xa0Crayton',
#  'Mike ScifresM.\xa0Scifres',
#  'Tom BradyT.\xa0Brady',
#  'Shaun HillS.\xa0Hill',
#  'Drew BreesD.\xa0Brees',
#  'Jon KitnaJ.\xa0Kitna',
#  'Carson PalmerC.\xa0Palmer',
#  'Chad JohnsonC.\xa0Johnson',
#  'Mark SanchezM.\xa0Sanchez',
#  'Brett FavreB.\xa0Favre',
#  'Donovan McNabbD.\xa0McNabb',
#  'Rusty SmithR.\xa0Smith',
#  'Matt SchaubM.\xa0Schaub',
#  'Josh FreemanJ.\xa0Freeman',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Matt RyanM.\xa0Ryan',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Jake DelhommeJ.\xa0Delhomme',
#  'Peyton HillisP.\xa0Hillis',
#  'Michael VickM.\xa0Vick',
#  'Jay CutlerJ.\xa0Cutler',
#  'Ben RoethlisbergerB.\xa0Roethlisberger',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'David GarrardD.\xa0Garrard',
#  'Eli ManningE.\xa0Manning',
#  'Chad HenneC.\xa0Henne',
#  'Bruce GradkowskiB.\xa0Gradkowski',
#  'Matt CasselM.\xa0Cassel',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Sam BradfordS.\xa0Bradford',
#  'Kyle OrtonK.\xa0Orton',
#  'Philip RiversP.\xa0Rivers',
#  'Peyton ManningP.\xa0Manning',
#  'Troy SmithT.\xa0Smith',
#  'Derek AndersonD.\xa0Anderson',
#  'Matt SchaubM.\xa0Schaub',
#  'Michael VickM.\xa0Vick',
#  'David GarrardD.\xa0Garrard',
#  'Kerry CollinsK.\xa0Collins',
#  'Jay CutlerJ.\xa0Cutler',
#  'Drew StantonD.\xa0Stanton',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'Tarvaris JacksonT.\xa0Jackson',
#  'Brett FavreB.\xa0Favre',
#  'Kyle OrtonK.\xa0Orton',
#  'Matt CasselM.\xa0Cassel',
#  'Matt RyanM.\xa0Ryan',
#  'Josh FreemanJ.\xa0Freeman',
#  'Earnest GrahamE.\xa0Graham',
#  'Troy SmithT.\xa0Smith',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Drew BreesD.\xa0Brees',
#  'Carson PalmerC.\xa0Palmer',
#  'Jake DelhommeJ.\xa0Delhomme',
#  'Chad HenneC.\xa0Henne',
#  'Donovan McNabbD.\xa0McNabb',
#  'Eli ManningE.\xa0Manning',
#  'Jason CampbellJ.\xa0Campbell',
#  'Philip RiversP.\xa0Rivers',
#  'Jon KitnaJ.\xa0Kitna',
#  'Peyton ManningP.\xa0Manning',
#  'Sam BradfordS.\xa0Bradford',
#  'Derek AndersonD.\xa0Anderson',
#  'John SkeltonJ.\xa0Skelton',
#  'Max HallM.\xa0Hall',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Leon WashingtonL.\xa0Washington',
#  'Ben RoethlisbergerB.\xa0Roethlisberger',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Mark SanchezM.\xa0Sanchez',
#  'Tom BradyT.\xa0Brady',
#  'Peyton ManningP.\xa0Manning',
#  'Kerry CollinsK.\xa0Collins',
#  'Josh FreemanJ.\xa0Freeman',
#  'Donovan McNabbD.\xa0McNabb',
#  'Matt RyanM.\xa0Ryan',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Armanti EdwardsA.\xa0Edwards',
#  'Carson PalmerC.\xa0Palmer',
#  'Ben RoethlisbergerB.\xa0Roethlisberger',
#  'Jason CampbellJ.\xa0Campbell',
#  'Kyle BollerK.\xa0Boller',
#  'David GarrardD.\xa0Garrard',
#  'Matt FlynnM.\xa0Flynn',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Drew StantonD.\xa0Stanton',
#  'Eli ManningE.\xa0Manning',
#  'Tarvaris JacksonT.\xa0Jackson',
#  'Joe WebbJ.\xa0Webb',
#  'Jake DelhommeJ.\xa0Delhomme',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'Tom BradyT.\xa0Brady',
#  'Jay CutlerJ.\xa0Cutler',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Alex SmithA.\xa0Smith',
#  'Sam BradfordS.\xa0Bradford',
#  'Drew BreesD.\xa0Brees',
#  'Brodie CroyleB.\xa0Croyle',
#  'Tyler PalkoT.\xa0Palko',
#  'Philip RiversP.\xa0Rivers',
#  'Chad HenneC.\xa0Henne',
#  'Ronnie BrownR.\xa0Brown',
#  'Mark SanchezM.\xa0Sanchez',
#  'Kyle OrtonK.\xa0Orton',
#  'John SkeltonJ.\xa0Skelton',
#  'Steve BreastonS.\xa0Breaston',
#  'Michael VickM.\xa0Vick',
#  'Jon KitnaJ.\xa0Kitna',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Matt SchaubM.\xa0Schaub',
#  'Alex SmithA.\xa0Smith',
#  'Philip RiversP.\xa0Rivers',
#  'David GarrardD.\xa0Garrard',
#  'Peyton ManningP.\xa0Manning',
#  'Matt CasselM.\xa0Cassel',
#  'Sam BradfordS.\xa0Bradford',
#  'Rex GrossmanR.\xa0Grossman',
#  'Jon KitnaJ.\xa0Kitna',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'Chad HenneC.\xa0Henne',
#  'Colt McCoyC.\xa0McCoy',
#  'Carson PalmerC.\xa0Palmer',
#  'Drew StantonD.\xa0Stanton',
#  'Stefan LoganS.\xa0Logan',
#  'Josh FreemanJ.\xa0Freeman',
#  'Josh JohnsonJ.\xa0Johnson',
#  'Matt SchaubM.\xa0Schaub',
#  'Kerry CollinsK.\xa0Collins',
#  'Michael VickM.\xa0Vick',
#  'Eli ManningE.\xa0Manning',
#  'Drew BreesD.\xa0Brees',
#  'Joe FlaccoJ.\xa0Flacco',
#  'John SkeltonJ.\xa0Skelton',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Matt RyanM.\xa0Ryan',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Charlie WhitehurstC.\xa0Whitehurst',
#  'Tim TebowT.\xa0Tebow',
#  'Jason CampbellJ.\xa0Campbell',
#  'Mark SanchezM.\xa0Sanchez',
#  'Ben RoethlisbergerB.\xa0Roethlisberger',
#  'Matt FlynnM.\xa0Flynn',
#  'Tom BradyT.\xa0Brady',
#  'Jay CutlerJ.\xa0Cutler',
#  'Joe WebbJ.\xa0Webb',
#  'Brett FavreB.\xa0Favre',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Ben RoethlisbergerB.\xa0Roethlisberger',
#  'Jon KitnaJ.\xa0Kitna',
#  'Stephen McGeeS.\xa0McGee',
#  'John SkeltonJ.\xa0Skelton',
#  'Troy SmithT.\xa0Smith',
#  'Alex SmithA.\xa0Smith',
#  'Sam BradfordS.\xa0Bradford',
#  'Tom BradyT.\xa0Brady',
#  'Ryan FitzpatrickR.\xa0Fitzpatrick',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Colt McCoyC.\xa0McCoy',
#  'Mohamed MassaquoiM.\xa0Massaquoi',
#  'Joe WebbJ.\xa0Webb',
#  'Michael VickM.\xa0Vick',
#  'Mark SanchezM.\xa0Sanchez',
#  'Brad SmithB.\xa0Smith',
#  'Jay CutlerJ.\xa0Cutler',
#  'Charlie WhitehurstC.\xa0Whitehurst',
#  'Matt HasselbeckM.\xa0Hasselbeck',
#  'Josh FreemanJ.\xa0Freeman',
#  'Josh JohnsonJ.\xa0Johnson',
#  'Rex GrossmanR.\xa0Grossman',
#  'David GarrardD.\xa0Garrard',
#  'Kerry CollinsK.\xa0Collins',
#  'Matt CasselM.\xa0Cassel',
#  'Brodie CroyleB.\xa0Croyle',
#  'Shaun HillS.\xa0Hill',
#  'Chad HenneC.\xa0Henne',
#  'Peyton ManningP.\xa0Manning',
#  'Jason CampbellJ.\xa0Campbell',
#  'Matt SchaubM.\xa0Schaub',
#  'Tim TebowT.\xa0Tebow',
#  'Eli ManningE.\xa0Manning',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Philip RiversP.\xa0Rivers',
#  'Carson PalmerC.\xa0Palmer',
#  'Drew BreesD.\xa0Brees',
#  'Matt RyanM.\xa0Ryan',
#  'Eli ManningE.\xa0Manning',
#  'Rex GrossmanR.\xa0Grossman',
#  'Stephen McGeeS.\xa0McGee',
#  'Kevin KolbK.\xa0Kolb',
#  'Jimmy ClausenJ.\xa0Clausen',
#  'Brandon LaFellB.\xa0LaFell',
#  'Matt RyanM.\xa0Ryan',
#  'Chris RedmanC.\xa0Redman',
#  'Josh FreemanJ.\xa0Freeman',
#  'Micheal SpurlockM.\xa0Spurlock',
#  'Drew BreesD.\xa0Brees',
#  'Chase DanielC.\xa0Daniel',
#  'Joe WebbJ.\xa0Webb',
#  'Shaun HillS.\xa0Hill',
#  'Brian BrohmB.\xa0Brohm',
#  'Levi BrownL.\xa0Brown',
#  'Mark BrunellM.\xa0Brunell',
#  'Kellen ClemensK.\xa0Clemens',
#  'Brad SmithB.\xa0Smith',
#  'Tyler ThigpenT.\xa0Thigpen',
#  'Chad HenneC.\xa0Henne',
#  'Tom BradyT.\xa0Brady',
#  'Brian HoyerB.\xa0Hoyer',
#  'Trent EdwardsT.\xa0Edwards',
#  'Matt SchaubM.\xa0Schaub',
#  'Jay CutlerJ.\xa0Cutler',
#  'Aaron RodgersA.\xa0Rodgers',
#  'Ben RoethlisbergerB.\xa0Roethlisberger',
#  'Byron LeftwichB.\xa0Leftwich',
#  'Antwaan Randle ElA.\xa0Randle El',
#  'Colt McCoyC.\xa0McCoy',
#  'Seneca WallaceS.\xa0Wallace',
#  'Joshua CribbsJ.\xa0Cribbs',
#  'Kerry CollinsK.\xa0Collins',
#  'Peyton ManningP.\xa0Manning',
#  'Jason CampbellJ.\xa0Campbell',
#  'Kyle BollerK.\xa0Boller',
#  'Matt CasselM.\xa0Cassel',
#  'Tyler PalkoT.\xa0Palko',
#  'Carson PalmerC.\xa0Palmer',
#  'Joe FlaccoJ.\xa0Flacco',
#  'Sam BradfordS.\xa0Bradford',
#  'Charlie WhitehurstC.\xa0Whitehurst',
#  'Richard BartelR.\xa0Bartel',
#  'John SkeltonJ.\xa0Skelton',
#  'Alex SmithA.\xa0Smith',
#  'Philip RiversP.\xa0Rivers',
#  'Tim TebowT.\xa0Tebow']

# %%
qb_list = []
for item in qb_col:
    qb = item.split(".")[0]
    qb = qb[:-1]
    qb_list.append(qb)
qb_list
# Out:
# ['Brett Favre',
#  'Drew Brees',
#  'Chad Henne',
#  'Trent Edwards',
#  'Matt Ryan',
#  'Dennis Dixon',
#  'Kyle Orton',
#  'David Garrard',
#  'Peyton Manning',
#  'Matt Schaub',
#  'Jake Delhomme',
#  'Joshua Cribbs',
#  'Josh Freeman',
#  'Matt Moore',
#  'Jimmy Clausen',
#  'Eli Manning',
#  'Carson Palmer',
#  'Tom Brady',
#  'Jason Campbell',
#  'Vince Young',
#  'Shaun Hill',
#  'Matthew Stafford',
#  'Jay Cutler',
#  'Derek Anderson',
#  'Sam Bradford',
#  'Aaron Rodgers',
#  'Michael Vick',
#  'Kevin Kolb',
#  'Alex Smith',
#  'Matt Hasselbeck',
#  'Tony Romo',
#  'Marion Barber',
#  'Donovan McNabb',
#  'Joe Flacco',
#  'Mark Sanchez',
#  'Philip Rivers',
#  'Matt Cassel',
#  'Charlie Batch',
#  'Dennis Dixon',
#  'Kerry Collins',
#  'Vince Young',
#  'Josh Freeman',
#  'Micheal Spurlock',
#  'Matt Moore',
#  'Jimmy Clausen',
#  'Matt Cassel',
#  'Seneca Wallace',
#  'Chad Henne',
#  'Brett Favre',
#  'Derek Anderson',
#  'Max Hall',
#  'Matt Ryan',
#  'Michael Vick',
#  'Shaun Hill',
#  'Jay Cutler',
#  'Tony Romo',
#  'Joe Flacco',
#  'Carson Palmer',
#  'Trent Edwards',
#  'Aaron Rodgers',
#  'Sam Bradford',
#  'Bruce Gradkowski',
#  'Jason Campbell',
#  'Matt Hasselbeck',
#  'Kyle Orton',
#  'Matt Schaub',
#  'Donovan McNabb',
#  'Tom Brady',
#  'Mark Sanchez',
#  'David Garrard',
#  'Luke McCown',
#  'Philip Rivers',
#  'Eli Manning',
#  'Peyton Manning',
#  'Drew Brees',
#  'Alex Smith',
#  'Ryan Fitzpatrick',
#  'Tom Brady',
#  'Shaun Hill',
#  'Brett Favre',
#  'Carson Palmer',
#  'Jimmy Clausen',
#  'Matt Ryan',
#  'Drew Brees',
#  'Charlie Batch',
#  'Josh Freeman',
#  'Josh Johnson',
#  'Seneca Wallace',
#  'Joe Flacco',
#  'Anquan Boldin',
#  'Vince Young',
#  'Eli Manning',
#  'Alex Smith',
#  'Matt Cassel',
#  'Tony Romo',
#  'Matt Schaub',
#  'Donovan McNabb',
#  'Sam Bradford',
#  'Michael Vick',
#  'David Garrard',
#  'Philip Rivers',
#  'Matt Hasselbeck',
#  'Bruce Gradkowski',
#  'Derek Anderson',
#  'Peyton Manning',
#  'Kyle Orton',
#  'Mark Sanchez',
#  'Chad Henne',
#  'Ronnie Brown',
#  'Aaron Rodgers',
#  'Jay Cutler',
#  'Mark Sanchez',
#  'Mark Brunell',
#  'Brad Smith',
#  'Ryan Fitzpatrick',
#  'Matt Hasselbeck',
#  'Michael Robinson',
#  'Sam Bradford',
#  'Alex Smith',
#  'Matt Ryan',
#  'Shaun Hill',
#  'Aaron Rodgers',
#  'Carson Palmer',
#  'Seneca Wallace',
#  'Kyle Orton',
#  'Vince Young',
#  'Jimmy Clausen',
#  'Drew Brees',
#  'Joe Flacco',
#  'Charlie Batch',
#  'Peyton Manning',
#  'David Garrard',
#  'Matt Schaub',
#  'Bruce Gradkowski',
#  'Donovan McNabb',
#  'Kevin Kolb',
#  'Michael Vick',
#  'Derek Anderson',
#  'Max Hall',
#  'Philip Rivers',
#  'Billy Volek',
#  'Todd Collins',
#  'Jay Cutler',
#  'Caleb Hanie',
#  'Eli Manning',
#  'Tom Brady',
#  'Chad Henne',
#  'Tyler Thigpen',
#  'Todd Collins',
#  'Caleb Hanie',
#  'Jimmy Clausen',
#  'Matt Moore',
#  'Matt Cassel',
#  'Peyton Manning',
#  'Matt Ryan',
#  'Jake Delhomme',
#  'Seneca Wallace',
#  'Joshua Cribbs',
#  'Kyle Orton',
#  'Joe Flacco',
#  'Eli Manning',
#  'Matt Schaub',
#  'Sam Bradford',
#  'Shaun Hill',
#  'Jahvid Best',
#  'Drew Stanton',
#  'Aaron Rodgers',
#  'Donovan McNabb',
#  'Josh Freeman',
#  'Josh Johnson',
#  'Carson Palmer',
#  'David Garrard',
#  'Ryan Fitzpatrick',
#  'Drew Brees',
#  'Max Hall',
#  'Derek Anderson',
#  'Philip Rivers',
#  'Jason Campbell',
#  'Bruce Gradkowski',
#  'Vince Young',
#  'Tony Romo',
#  'Kevin Kolb',
#  'Alex Smith',
#  'Brett Favre',
#  'Mark Sanchez',
#  'Matt Ryan',
#  'Kevin Kolb',
#  'Philip Rivers',
#  'Sam Bradford',
#  'Drew Brees',
#  'Josh Freeman',
#  'Josh Johnson',
#  'Drew Stanton',
#  'Shaun Hill',
#  'Eli Manning',
#  'Chad Henne',
#  'Aaron Rodgers',
#  'Matt Hasselbeck',
#  'Jay Cutler',
#  'Joe Flacco',
#  'Tom Brady',
#  'Colt McCoy',
#  'Joshua Cribbs',
#  'Ben Roethlisberger',
#  'Matt Cassel',
#  'Matt Schaub',
#  'Mark Sanchez',
#  'Kyle Orton',
#  'Jason Campbell',
#  'Alex Smith',
#  'Tony Romo',
#  'Brett Favre',
#  'Peyton Manning',
#  'Donovan McNabb',
#  'Kerry Collins',
#  'Vince Young',
#  'Trent Edwards',
#  'David Garrard',
#  'Kevin Kolb',
#  'Kerry Collins',
#  'Alex Smith',
#  'David Carr',
#  'Matt Moore',
#  'Todd Bouman',
#  'Matt Cassel',
#  'Ben Roethlisberger',
#  'Chad Henne',
#  'Carson Palmer',
#  'Matt Ryan',
#  'Donovan McNabb',
#  'Jay Cutler',
#  'Colt McCoy',
#  'Peyton Hillis',
#  'Drew Brees',
#  'Ryan Fitzpatrick',
#  'Joe Flacco',
#  'Sam Bradford',
#  'Josh Freeman',
#  'Derek Anderson',
#  'Max Hall',
#  'Matt Hasselbeck',
#  'Jason Campbell',
#  'Kyle Orton',
#  'Tom Brady',
#  'Philip Rivers',
#  'Brett Favre',
#  'Aaron Rodgers',
#  'Matt Flynn',
#  'Eli Manning',
#  'Jon Kitna',
#  'Tony Romo',
#  'Matt Moore',
#  'Sam Bradford',
#  'Ryan Fitzpatrick',
#  'Matt Cassel',
#  'David Garrard',
#  'Jon Kitna',
#  'Chad Henne',
#  'Carson Palmer',
#  'Aaron Rodgers',
#  'Mark Sanchez',
#  'Donovan McNabb',
#  'Rex Grossman',
#  'Matthew Stafford',
#  'Kyle Orton',
#  'Troy Smith',
#  'Vince Young',
#  'Kerry Collins',
#  'Philip Rivers',
#  'Josh Freeman',
#  'Derek Anderson',
#  'Max Hall',
#  'Matt Hasselbeck',
#  'Jason Campbell',
#  'Brett Favre',
#  'Tarvaris Jackson',
#  'Tom Brady',
#  'Ben Roethlisberger',
#  'Drew Brees',
#  'Matt Schaub',
#  'Peyton Manning',
#  'Philip Rivers',
#  'Matt Schaub',
#  'Chad Henne',
#  'Joe Flacco',
#  'Sam Koch',
#  'Jay Cutler',
#  'Ryan Fitzpatrick',
#  'Josh Freeman',
#  'Matt Ryan',
#  'Tom Brady',
#  'Brian Hoyer',
#  'Colt McCoy',
#  'Drew Brees',
#  'Chase Daniel',
#  'Jimmy Clausen',
#  'Tony Pike',
#  'Matt Moore',
#  'Derek Anderson',
#  'Steve Breaston',
#  'Brett Favre',
#  'Mark Sanchez',
#  'Matthew Stafford',
#  'Drew Stanton',
#  'Eli Manning',
#  'Charlie Whitehurst',
#  'Matt Cassel',
#  'Jason Campbell',
#  'Darren McFadden',
#  'Peyton Manning',
#  'Michael Vick',
#  'Jon Kitna',
#  'Aaron Rodgers',
#  'Matt Flynn',
#  'Ben Roethlisberger',
#  'Antwaan Randle El',
#  'Carson Palmer',
#  'Joe Flacco',
#  'Matt Ryan',
#  'Shaun Hill',
#  'Ryan Fitzpatrick',
#  'Matt Schaub',
#  'David Garrard',
#  'Kerry Collins',
#  'Vince Young',
#  'Chad Henne',
#  'Tyler Thigpen',
#  'Chad Pennington',
#  'Brandon Marshall',
#  'Brett Favre',
#  'Jay Cutler',
#  'Mark Sanchez',
#  'Colt McCoy',
#  'Carson Palmer',
#  'Peyton Manning',
#  'Jimmy Clausen',
#  'Josh Freeman',
#  'Matt Cassel',
#  'Kyle Orton',
#  'Tim Tebow',
#  'Matt Hasselbeck',
#  'Charlie Whitehurst',
#  'Derek Anderson',
#  'Jon Kitna',
#  'Eli Manning',
#  'Sam Bradford',
#  'Troy Smith',
#  'Tom Brady',
#  'Ben Roethlisberger',
#  'Michael Vick',
#  'Donovan McNabb',
#  'Jay Cutler',
#  'Tyler Thigpen',
#  'Aaron Rodgers',
#  'Matt Flynn',
#  'Brett Favre',
#  'Joe Flacco',
#  'Brian S',
#  'Matt Schaub',
#  'Mark Sanchez',
#  'Donovan McNabb',
#  'Vince Young',
#  'Rusty Smith',
#  'Ryan Fitzpatrick',
#  'Carson Palmer',
#  'Jordan Palmer',
#  'Colt McCoy',
#  'David Garrard',
#  'Maurice Jones-Drew',
#  'Shaun Hill',
#  'Jon Kitna',
#  'Bruce Gradkowski',
#  'Jason Campbell',
#  'Ben Roethlisberger',
#  'Derek Anderson',
#  'Matt Cassel',
#  'Matt Ryan',
#  'Sam Bradford',
#  'Josh Freeman',
#  'Josh Johnson',
#  'Micheal Spurlock',
#  'Troy Smith',
#  'Matt Hasselbeck',
#  'Drew Brees',
#  'Peyton Manning',
#  'Tom Brady',
#  'Eli Manning',
#  'Michael Vick',
#  'Kyle Orton',
#  'Philip Rivers',
#  'Patrick Crayton',
#  'Mike Scifres',
#  'Tom Brady',
#  'Shaun Hill',
#  'Drew Brees',
#  'Jon Kitna',
#  'Carson Palmer',
#  'Chad Johnson',
#  'Mark Sanchez',
#  'Brett Favre',
#  'Donovan McNabb',
#  'Rusty Smith',
#  'Matt Schaub',
#  'Josh Freeman',
#  'Joe Flacco',
#  'Aaron Rodgers',
#  'Matt Ryan',
#  'Jimmy Clausen',
#  'Jake Delhomme',
#  'Peyton Hillis',
#  'Michael Vick',
#  'Jay Cutler',
#  'Ben Roethlisberger',
#  'Ryan Fitzpatrick',
#  'David Garrard',
#  'Eli Manning',
#  'Chad Henne',
#  'Bruce Gradkowski',
#  'Matt Cassel',
#  'Matt Hasselbeck',
#  'Sam Bradford',
#  'Kyle Orton',
#  'Philip Rivers',
#  'Peyton Manning',
#  'Troy Smith',
#  'Derek Anderson',
#  'Matt Schaub',
#  'Michael Vick',
#  'David Garrard',
#  'Kerry Collins',
#  'Jay Cutler',
#  'Drew Stanton',
#  'Ryan Fitzpatrick',
#  'Tarvaris Jackson',
#  'Brett Favre',
#  'Kyle Orton',
#  'Matt Cassel',
#  'Matt Ryan',
#  'Josh Freeman',
#  'Earnest Graham',
#  'Troy Smith',
#  'Aaron Rodgers',
#  'Drew Brees',
#  'Carson Palmer',
#  'Jake Delhomme',
#  'Chad Henne',
#  'Donovan McNabb',
#  'Eli Manning',
#  'Jason Campbell',
#  'Philip Rivers',
#  'Jon Kitna',
#  'Peyton Manning',
#  'Sam Bradford',
#  'Derek Anderson',
#  'John Skelton',
#  'Max Hall',
#  'Jimmy Clausen',
#  'Matt Hasselbeck',
#  'Leon Washington',
#  'Ben Roethlisberger',
#  'Joe Flacco',
#  'Mark Sanchez',
#  'Tom Brady',
#  'Peyton Manning',
#  'Kerry Collins',
#  'Josh Freeman',
#  'Donovan McNabb',
#  'Matt Ryan',
#  'Jimmy Clausen',
#  'Armanti Edwards',
#  'Carson Palmer',
#  'Ben Roethlisberger',
#  'Jason Campbell',
#  'Kyle Boller',
#  'David Garrard',
#  'Matt Flynn',
#  'Aaron Rodgers',
#  'Drew Stanton',
#  'Eli Manning',
#  'Tarvaris Jackson',
#  'Joe Webb',
#  'Jake Delhomme',
#  'Ryan Fitzpatrick',
#  'Tom Brady',
#  'Jay Cutler',
#  'Matt Hasselbeck',
#  'Alex Smith',
#  'Sam Bradford',
#  'Drew Brees',
#  'Brodie Croyle',
#  'Tyler Palko',
#  'Philip Rivers',
#  'Chad Henne',
#  'Ronnie Brown',
#  'Mark Sanchez',
#  'Kyle Orton',
#  'John Skelton',
#  'Steve Breaston',
#  'Michael Vick',
#  'Jon Kitna',
#  'Joe Flacco',
#  'Matt Schaub',
#  'Alex Smith',
#  'Philip Rivers',
#  'David Garrard',
#  'Peyton Manning',
#  'Matt Cassel',
#  'Sam Bradford',
#  'Rex Grossman',
#  'Jon Kitna',
#  'Ryan Fitzpatrick',
#  'Chad Henne',
#  'Colt McCoy',
#  'Carson Palmer',
#  'Drew Stanton',
#  'Stefan Logan',
#  'Josh Freeman',
#  'Josh Johnson',
#  'Matt Schaub',
#  'Kerry Collins',
#  'Michael Vick',
#  'Eli Manning',
#  'Drew Brees',
#  'Joe Flacco',
#  'John Skelton',
#  'Jimmy Clausen',
#  'Matt Ryan',
#  'Matt Hasselbeck',
#  'Charlie Whitehurst',
#  'Tim Tebow',
#  'Jason Campbell',
#  'Mark Sanchez',
#  'Ben Roethlisberger',
#  'Matt Flynn',
#  'Tom Brady',
#  'Jay Cutler',
#  'Joe Webb',
#  'Brett Favre',
#  'Jimmy Clausen',
#  'Ben Roethlisberger',
#  'Jon Kitna',
#  'Stephen McGee',
#  'John Skelton',
#  'Troy Smith',
#  'Alex Smith',
#  'Sam Bradford',
#  'Tom Brady',
#  'Ryan Fitzpatrick',
#  'Joe Flacco',
#  'Colt McCoy',
#  'Mohamed Massaquoi',
#  'Joe Webb',
#  'Michael Vick',
#  'Mark Sanchez',
#  'Brad Smith',
#  'Jay Cutler',
#  'Charlie Whitehurst',
#  'Matt Hasselbeck',
#  'Josh Freeman',
#  'Josh Johnson',
#  'Rex Grossman',
#  'David Garrard',
#  'Kerry Collins',
#  'Matt Cassel',
#  'Brodie Croyle',
#  'Shaun Hill',
#  'Chad Henne',
#  'Peyton Manning',
#  'Jason Campbell',
#  'Matt Schaub',
#  'Tim Tebow',
#  'Eli Manning',
#  'Aaron Rodgers',
#  'Philip Rivers',
#  'Carson Palmer',
#  'Drew Brees',
#  'Matt Ryan',
#  'Eli Manning',
#  'Rex Grossman',
#  'Stephen McGee',
#  'Kevin Kolb',
#  'Jimmy Clausen',
#  'Brandon LaFell',
#  'Matt Ryan',
#  'Chris Redman',
#  'Josh Freeman',
#  'Micheal Spurlock',
#  'Drew Brees',
#  'Chase Daniel',
#  'Joe Webb',
#  'Shaun Hill',
#  'Brian Brohm',
#  'Levi Brown',
#  'Mark Brunell',
#  'Kellen Clemens',
#  'Brad Smith',
#  'Tyler Thigpen',
#  'Chad Henne',
#  'Tom Brady',
#  'Brian Hoyer',
#  'Trent Edwards',
#  'Matt Schaub',
#  'Jay Cutler',
#  'Aaron Rodgers',
#  'Ben Roethlisberger',
#  'Byron Leftwich',
#  'Antwaan Randle El',
#  'Colt McCoy',
#  'Seneca Wallace',
#  'Joshua Cribbs',
#  'Kerry Collins',
#  'Peyton Manning',
#  'Jason Campbell',
#  'Kyle Boller',
#  'Matt Cassel',
#  'Tyler Palko',
#  'Carson Palmer',
#  'Joe Flacco',
#  'Sam Bradford',
#  'Charlie Whitehurst',
#  'Richard Bartel',
#  'John Skelton',
#  'Alex Smith',
#  'Philip Rivers',
#  'Tim Tebow']

# %%
qb_df["qb"] = qb_list

# %%
qb_df.head()
# Out:
#               qb  att  cmp  yds  ypa  td  int   lg  sack  loss   rate  \
# 0    Brett Favre   27   15  171  6.3   1    1   33     1     9   71.7
# 1     Drew Brees   36   27  237  6.6   1    0  29t     1     8  101.3
# 2     Chad Henne   34   21  182  5.4   0    0   21     3    18   75.9
# 3  Trent Edwards   34   18  139  4.1   1    0  31t     3    23   73.0
# 4      Matt Ryan   44   27  252  5.7   0    1   23     2    15   67.6
#
#    game_points home_away  year
# 0            9      away  2010
# 1           14      home  2010
# 2           15      away  2010
# 3           10      home  2010
# 4            9      away  2010

# %%
qb_df.drop(['att','cmp', 'yds'
           ,'ypa','td','int'
           ,'lg','sack','loss'
           ,'game_points','home_away'
           ,'year'], axis=1, inplace=True)
qb_df.rename(columns={'qb': 'qb_name', 'rate': 'qb_rating'}, inplace=True)

# %%
qb_df
# Out:
#                 qb_name  qb_rating
# 0           Brett Favre       71.7
# 1            Drew Brees      101.3
# 2            Chad Henne       75.9
# 3         Trent Edwards       73.0
# 4             Matt Ryan       67.6
# 5          Dennis Dixon       81.6
# 6            Kyle Orton       89.8
# 7         David Garrard      138.9
# 8        Peyton Manning      109.8
# 9           Matt Schaub       67.5
# 10        Jake Delhomme       59.2
# 11        Joshua Cribbs      104.2
# 12         Josh Freeman       88.7
# 13           Matt Moore       32.6
# 14        Jimmy Clausen       39.6
# 15          Eli Manning       87.9
# 16        Carson Palmer       92.5
# 17            Tom Brady      120.9
# 18       Jason Campbell       69.7
# 19          Vince Young      142.8
# 20           Shaun Hill       38.9
# 21     Matthew Stafford       86.2
# 22           Jay Cutler      108.3
# 23       Derek Anderson       85.1
# 24         Sam Bradford       53.1
# 25        Aaron Rodgers       73.1
# 26         Michael Vick      101.9
# 27           Kevin Kolb       56.2
# 28           Alex Smith       52.5
# 29      Matt Hasselbeck      108.3
# ..                  ...        ...
# 595          Brad Smith       79.2
# 596       Tyler Thigpen       91.2
# 597          Chad Henne       25.8
# 598           Tom Brady      145.6
# 599         Brian Hoyer      111.7
# 600       Trent Edwards       62.1
# 601         Matt Schaub      129.7
# 602          Jay Cutler       43.5
# 603       Aaron Rodgers       89.7
# 604  Ben Roethlisberger      141.3
# 605      Byron Leftwich       86.6
# 606   Antwaan Randle El      118.8
# 607          Colt McCoy       41.6
# 608      Seneca Wallace       79.2
# 609       Joshua Cribbs       39.6
# 610       Kerry Collins      111.1
# 611      Peyton Manning      100.1
# 612      Jason Campbell       91.2
# 613         Kyle Boller       87.5
# 614         Matt Cassel       19.1
# 615         Tyler Palko       95.1
# 616       Carson Palmer       78.5
# 617          Joe Flacco       69.0
# 618        Sam Bradford       52.4
# 619  Charlie Whitehurst       84.5
# 620      Richard Bartel       57.1
# 621        John Skelton       60.8
# 622          Alex Smith      107.8
# 623       Philip Rivers       73.4
# 624           Tim Tebow       58.2
#
# [625 rows x 2 columns]

# %%
qb_df.to_csv()
# Out:
# ',qb_name,qb_rating\r\n0,Brett Favre,71.7\r\n1,Drew Brees,101.3\r\n2,Chad Henne,75.9\r\n3,Trent Edwards,73.0\r\n4,Matt Ryan,67.6\r\n5,Dennis Dixon,81.6\r\n6,Kyle Orton,89.8\r\n7,David Garrard,138.9\r\n8,Peyton Manning,109.8\r\n9,Matt Schaub,67.5\r\n10,Jake Delhomme,59.2\r\n11,Joshua Cribbs,104.2\r\n12,Josh Freeman,88.7\r\n13,Matt Moore,32.6\r\n14,Jimmy Clausen,39.6\r\n15,Eli Manning,87.9\r\n16,Carson Palmer,92.5\r\n17,Tom Brady,120.9\r\n18,Jason Campbell,69.7\r\n19,Vince Young,142.8\r\n20,Shaun Hill,38.9\r\n21,Matthew Stafford,86.2\r\n22,Jay Cutler,108.3\r\n23,Derek Anderson,85.1\r\n24,Sam Bradford,53.1\r\n25,Aaron Rodgers,73.1\r\n26,Michael Vick,101.9\r\n27,Kevin Kolb,56.2\r\n28,Alex Smith,52.5\r\n29,Matt Hasselbeck,108.3\r\n30,Tony Romo,89.1\r\n31,Marion Barber,39.6\r\n32,Donovan McNabb,63.4\r\n33,Joe Flacco,62.2\r\n34,Mark Sanchez,56.4\r\n35,Philip Rivers,98.0\r\n36,Matt Cassel,68.0\r\n37,Charlie Batch,52.5\r\n38,Dennis Dixon,70.1\r\n39,Kerry Collins,80.3\r\n40,Vince Young,48.3\r\n41,Josh Freeman,102.4\r\n42,Micheal Spurlock,39.6\r\n43,Matt Moore,60.7\r\n44,Jimmy Clausen,33.8\r\n45,Matt Cassel,46.1\r\n46,Seneca Wallace,73.2\r\n47,Chad Henne,106.0\r\n48,Brett Favre,44.3\r\n49,Derek Anderson,42.5\r\n50,Max Hall,16.7\r\n51,Matt Ryan,117.3\r\n52,Michael Vick,108.0\r\n53,Shaun Hill,75.7\r\n54,Jay Cutler,136.7\r\n55,Tony Romo,78.4\r\n56,Joe Flacco,23.8\r\n57,Carson Palmer,60.1\r\n58,Trent Edwards,37.0\r\n59,Aaron Rodgers,116.3\r\n60,Sam Bradford,86.6\r\n61,Bruce Gradkowski,73.9\r\n62,Jason Campbell,42.9\r\n63,Matt Hasselbeck,51.3\r\n64,Kyle Orton,117.2\r\n65,Matt Schaub,114.0\r\n66,Donovan McNabb,119.0\r\n67,Tom Brady,72.5\r\n68,Mark Sanchez,124.3\r\n69,David Garrard,62.7\r\n70,Luke McCown,76.6\r\n71,Philip Rivers,119.0\r\n72,Eli Manning,85.6\r\n73,Peyton Manning,145.5\r\n74,Drew Brees,108.9\r\n75,Alex Smith,82.2\r\n76,Ryan Fitzpatrick,92.4\r\n77,Tom Brady,142.6\r\n78,Shaun Hill,69.6\r\n79,Brett Favre,68.4\r\n80,Carson Palmer,53.3\r\n81,Jimmy Clausen,53.6\r\n82,Matt Ryan,108.8\r\n83,Drew Brees,111.1\r\n84,Charlie Batch,106.5\r\n85,Josh Freeman,67.1\r\n86,Josh Johnson,113.2\r\n87,Seneca Wallace,103.0\r\n88,Joe Flacco,128.7\r\n89,Anquan Boldin,79.2\r\n90,Vince Young,105.7\r\n91,Eli Manning,77.3\r\n92,Alex Smith,68.8\r\n93,Matt Cassel,111.7\r\n94,Tony Romo,127.6\r\n95,Matt Schaub,77.7\r\n96,Donovan McNabb,79.7\r\n97,Sam Bradford,78.1\r\n98,Michael Vick,119.2\r\n99,David Garrard,38.9\r\n100,Philip Rivers,80.3\r\n101,Matt Hasselbeck,77.6\r\n102,Bruce Gradkowski,72.5\r\n103,Derek Anderson,69.7\r\n104,Peyton Manning,109.2\r\n105,Kyle Orton,89.5\r\n106,Mark Sanchez,120.5\r\n107,Chad Henne,91.4\r\n108,Ronnie Brown,39.6\r\n109,Aaron Rodgers,92.5\r\n110,Jay Cutler,82.5\r\n111,Mark Sanchez,106.4\r\n112,Mark Brunell,95.8\r\n113,Brad Smith,118.8\r\n114,Ryan Fitzpatrick,83.6\r\n115,Matt Hasselbeck,58.9\r\n116,Michael Robinson,118.8\r\n117,Sam Bradford,84.3\r\n118,Alex Smith,65.6\r\n119,Matt Ryan,67.3\r\n120,Shaun Hill,77.0\r\n121,Aaron Rodgers,105.3\r\n122,Carson Palmer,121.4\r\n123,Seneca Wallace,74.9\r\n124,Kyle Orton,93.8\r\n125,Vince Young,90.3\r\n126,Jimmy Clausen,90.6\r\n127,Drew Brees,90.2\r\n128,Joe Flacco,82.7\r\n129,Charlie Batch,57.8\r\n130,Peyton Manning,99.2\r\n131,David Garrard,127.7\r\n132,Matt Schaub,98.6\r\n133,Bruce Gradkowski,78.8\r\n134,Donovan McNabb,60.2\r\n135,Kevin Kolb,76.0\r\n136,Michael Vick,90.8\r\n137,Derek Anderson,23.2\r\n138,Max Hall,74.1\r\n139,Philip Rivers,148.1\r\n140,Billy Volek,100.0\r\n141,Todd Collins,8.1\r\n142,Jay Cutler,40.7\r\n143,Caleb Hanie,102.1\r\n144,Eli Manning,79.2\r\n145,Tom Brady,107.1\r\n146,Chad Henne,81.6\r\n147,Tyler Thigpen,2.8\r\n148,Todd Collins,6.2\r\n149,Caleb Hanie,84.0\r\n150,Jimmy Clausen,29.7\r\n151,Matt Moore,18.8\r\n152,Matt Cassel,70.5\r\n153,Peyton Manning,65.0\r\n154,Matt Ryan,89.4\r\n155,Jake Delhomme,30.5\r\n156,Seneca Wallace,124.0\r\n157,Joshua Cribbs,108.3\r\n158,Kyle Orton,104.5\r\n159,Joe Flacco,81.4\r\n160,Eli Manning,89.1\r\n161,Matt Schaub,53.1\r\n162,Sam Bradford, ...

# %%
rds_connection_string = "postgres:postgres@localhost:5432/qb_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()

# %%
qb_df.to_sql(name='qb_rating', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from qb_rating', con=engine).head()
